# %%
import pandas as pd

# %%
#emissionshackmit
#facility name
#parent company name

# %%
sf6_2017 = pd.read_csv('2017sf6.csv')
sf6_2017
#T_sf6_2020 = sf6_2020[[" Facility Name", "SF6 emissions"]]
# Out:
#     Facility Id        FRS Id                         Facility Name  \
# 0       1003708  1.100010e+11           AEP Corporate SF6 Emissions
# 1       1010811  1.100110e+11              Ameren Illinois Electric
# 2       1010812  1.100120e+11              Ameren Missouri Electric
# 3       1010076  1.100560e+11  Anaheim Electric Distribution System
# 4       1009780  1.100120e+11        Arizona Public Service Company
# ..          ...           ...                                   ...
# 72      1009917  1.100170e+11         Transmission and Distribution
# 73      1008193  1.100120e+11         Tucson Electric Power Company
# 74      1010321  1.100560e+11        Vermont Electric Power Company
# 75      1009971  1.100210e+11   Virginia Electric and Power Company
# 76      1010171  1.100160e+11                                  WAPA
#
#    Reported City Reported State  Reported Zip Code  \
# 0       Columbus             OH              43215
# 1         Peoria             IL              61602
# 2      St. Louis             MO              63103
# 3        Anaheim             CA              92805
# 4        Phoenix             AZ              85021
# ..           ...            ...                ...
# 72   El Paso, TX             TX              79901
# 73        Tucson             AZ              85701
# 74       Rutland             VT               5701
# 75      Richmond             VA              23219
# 76      Lakewood             CO              80228
#
#                  Reported Address    Reported County  Reported Latitude  \
# 0               1 Riverside Plaza  WASHINGTON COUNTY          39.588493
# 1              300 Liberty Street      PEORIA COUNTY          40.690480
# 2            1901 Chouteau Avenue     ST. LOUIS CITY          38.620785
# 3   201 S. Anaheim Blvd., MS-1101      ORANGE COUNTY          33.834580
# 4             2124 W. Cheryl Ave.    MARICOPA COUNTY          33.578425
# ..                            ...                ...                ...
# 72      100 North Stanton Street      EL PASO COUNTY          31.758530
# 73         88 East Broadway Blvd.        PIMA COUNTY          32.163060
# 74          366 Pinnacle Ridge Rd     RUTLAND COUNTY          43.661080
# 75            120 Tredegar Street      RICHMOND CITY          37.533948
# 76     12155 West Alameda Parkway   JEFFERSON COUNTY          39.706100
#
#     Reported Longitude  Primary NAICS Code Industry Type (subparts)  \
# 0           -81.682523              221112                       DD
# 1           -89.592440              221122                       DD
# 2           -90.211635              221122                       DD
# 3          -117.914010              221122                       DD
# 4          -112.104408              221121                       DD
# ..                 ...                 ...                      ...
# 72         -106.485870              221112                       DD
# 73         -110.897450              221122                       DD
# 74          -72.992600              221121                       DD
# 75          -77.452741              221121                       DD
# 76         -105.136700              221122                       DD
#
#    Total reported direct emissions from Electrical Equipment Use  \
# 0                                          197,281.56
# 1                                            9,888.36
# 2                                           20,301.12
# 3                                            1,422.72
# 4                                           14,897.52
# ..                                                ...
# 72                                           3,748.32
# 73                                          11,238.12
# 74                                              387.6
# 75                                          42,266.64
# 76                                          10,011.48
#
#    SF6 emissions  Does the facility employ continuous emissions monitoring?
# 0      197,281.56                                                  N
# 1        9,888.36                                                  N
# 2       20,301.12                                                  N
# 3        1,422.72                                                  N
# 4       14,897.52                                                  N
# ..            ...                                                ...
# 72       3,748.32                                                  N
# 73      11,238.12                                                  N
# 74          387.6                                                  N
# 75      42,266.64                                                  N
# 76      10,011.48                                                  N
#
# [77 rows x 15 columns]

# %%
p_2017 = pd.read_csv('2017_parent_company.csv') 
p_2018 = pd.read_csv('2018_parent_company.csv')
p_2019 = pd.read_csv('2019_parent_company.csv')
p_2020 = pd.read_csv('2020_parent_company.csv')

T_2017 = p_2017[["FACILITY NAME", "PARENT COMPANY NAME", "FACILITY NAICS CODE"]]
T_2018 = p_2018[["FACILITY NAME", "PARENT COMPANY NAME", "FACILITY NAICS CODE"]]
T_2019 = p_2019[["FACILITY NAME", "PARENT COMPANY NAME", "FACILITY NAICS CODE"]]
T_2020 = p_2020[["FACILITY NAME", "PARENT COMPANY NAME", "FACILITY NAICS CODE"]]

de_2017 = pd.read_csv('2017de.csv')
sf6_2017 = pd.read_csv('2017sf6.csv')
de_2018 = pd.read_csv('2018de.csv')
sf6_2018 = pd.read_csv('2018sf6.csv')
de_2019 = pd.read_csv('2019de.csv')
sf6_2019 = pd.read_csv('2019sf6.csv')
de_2020 = pd.read_csv('2020de.csv')
sf6_2020 = pd.read_csv('2020sf6.csv')

T_de_2017 = de_2017[["Facility Name", "Total reported direct emissions"]]
T_sf6_2017 = sf6_2017[["Facility Name", "SF6 emissions"]]
T_de_2018 = de_2018[["Facility Name", "Total reported direct emissions"]]
T_sf6_2018 = sf6_2018[["Facility Name", "TSF6 emissions"]]
T_de_2019 = de_2019[["Facility Name", "Total reported direct emissions"]]
T_sf6_2019 = sf6_2019[["Facility Name", "SF6 emissions"]]
T_de_2020 = de_2020[["Facility Name", "Total reported direct emissions"]]
T_sf6_2020 = sf6_2020[["Facility Name", "SF6 emissions"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-87-89ad6a2197c8> in <module>
#      19
#      20 T_de_2017 = de_2017[["Facility Name", "Total reported direct emissions"]]
# ---> 21 T_sf6_2017 = sf6_2017[["Facility Name", "SF6 emissions"]]
#      22 T_de_2018 = de_2018[["Facility Name", "Total reported direct emissions"]]
#      23 T_sf6_2018 = sf6_2018[["Facility Name", "TSF6 emissions"]]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1314             if raise_missing:
#    1315                 not_found = list(set(key) - set(ax))
# -> 1316                 raise KeyError(f"{not_found} not in index")
#    1317
#    1318             not_found = key[missing_mask]
#
# KeyError: "['SF6 emissions'] not in index"

# %%
result = (T_de_2017.merge, T_sf6_2017[['Facility Name', 'SF6 emissions', 'Total reported direct emissions']], 
on =='Facility Name', how =='left')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-62dbebc1b68b> in <module>
# ----> 1 result = (T_de_2017.merge, T_sf6_2017[['Facility Name', 'SF6 emissions', 'Total reported direct emissions']],
#       2 on =='Facility Name', how =='left')
#
# NameError: name 'T_de_2017' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-86-bf52575f33fb> in <module>
# ----> 1 T_de_2017 = de_2017[["Facility Name", "Total reported direct emissions"]]
#       2 T_sf6_2017 = sf6_2017[["Facility Name", "SF6 emissions"]]
#       3 T_de_2018 = de_2018[["Facility Name", "Total reported direct emissions"]]
#       4 T_sf6_2018 = sf6_2018[["Facility Name", "TSF6 emissions"]]
#       5 T_de_2019 = de_2019[["Facility Name", "Total reported direct emissions"]]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1306             if missing == len(indexer):
#    1307                 axis_name = self.obj._get_axis_name(axis)
# -> 1308                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1309
#    1310             ax = self.obj._get_axis(axis)
#
# KeyError: "None of [Index(['Facility Name', 'Total reported direct emissions'], dtype='object')] are in the [columns]"
